# %%
from pythainlp.util import normalize
import pandas as pd

# %%
df = pd.read_csv("clean_text.csv", encoding="utf-8")

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#                                           tweet_text  is_toxic
# 0  วันๆ นี่คุยกะหมา แมว หมู ไก่ ม้า ควาย มากกว่าค...         0
# 1        หล่อมากกก หล่อวัวตายควายล้มกันเลยทีเดียวววว         0
# 2  สิวเหี้ยไรขึ้นหลังหู เสียชาติเกิดมั้ย เกิดมามั...         0
# 3  อ่ะ ป่วยก็ป่วย งานจ้างก็ต้องทำ งานเรียนก็ต้องท...         0
# 4  นี่ก็เพิ่งรู้ว่า เกิดชาตินี้ชาติเดียว เป็นทั้ง...         1

# %%
df['tweet_text'] = df['tweet_text'].apply(normalize)

# %%
df.head()
# Out:
#                                           tweet_text  is_toxic
# 0  วันๆ นี่คุยกะหมา แมว หมู ไก่ ม้า ควาย มากกว่าค...         0
# 1        หล่อมากกก หล่อวัวตายควายล้มกันเลยทีเดียวววว         0
# 2  สิวเหี้ยไรขึ้นหลังหู เสียชาติเกิดมั้ย เกิดมามั...         0
# 3  อ่ะ ป่วยก็ป่วย งานจ้างก็ต้องทำ งานเรียนก็ต้องท...         0
# 4  นี่ก็เพิ่งรู้ว่า เกิดชาตินี้ชาติเดียว เป็นทั้ง...         1

# %%
from pythainlp.tokenize import word_tokenize

# %%
df['tweet_text'] = df['tweet_text'].apply(lambda x: word_tokenize(x,engine='deepcut'))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# ...
# 4/4 [==============================] - 0s 3ms/step
# ...
# ...
# 3/3 [==============================] - 0s 3ms/step

# %%
df['tweet_text']
# Out:
# 0       [วัน, ๆ,  , นี่, คุย, กะหมา,  , แมว,  , หมู,  ...
# 1       [หล่อ, มาก, กก,  , หล่อ, วัว, ตาย, ควาย, ล้ม, ...
# 2       [สิวเหี้ยไร, ขึ้น, หลัง, หู,  , เสียชาติ, เกิด...
# 3       [อ่ะ,  , ป่วย, ก็, ป่วย,  , งาน, จ้าง, ก็, ต้อ...
# 4       [นี่, ก็, เพิ่ง, รู้, ว่า,  , เกิด, ชาติ, นี้,...
#                               ...
# 2155    [อินเดีย, เป็น, ประเทศ, ที่, เหี้ยสัสหมา, จริง...
# 2156    [ควย,  , การ, ตอบ, ว่า, เสือก, นี่, แม่ง, ไม่,...
# 2157    [ส้น, ตีน, มาก, ค่ะ,  , อาเซียน, ร่วมใจ, จริง,...
# 2158    [ไม่, สวย, ก็, เหนื่อย, หน่อย,  , ไม่, หน่อย, ...
# 2159    [นี่, คือ, ประเทศไทย, ใน, ความ, จริง,  , คน, ช...
# Name: tweet_text, Length: 2160, dtype: object

# %% [markdown]
# ## **Pytorch :)**

# %% [markdown]
# #### Train - Test spilt

# %%
from torch.utils.data import random_split ,DataLoader

# %%
train_size = int(0.8 * len(df))
test_size = len(df) - train_size
train_dataset, test_dataset = random_split(df, [train_size, test_size])

# %%
len(train_dataset), len(test_dataset)
# Out:
# (1728, 432)

# %%
tokenizer = word_tokenize()
tokenizer.fit_on_texts(train_dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tokenizer = word_tokenize()
#       2 tokenizer.fit_on_texts(train_dataset)
#
# TypeError: word_tokenize() missing 1 required positional argument: 'text'

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
print("hello world")
# Out:
# hello world
