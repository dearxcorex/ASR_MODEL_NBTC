# %% [markdown]
# <a href="https://colab.research.google.com/github/dearxcorex/ASR_MODEL_NBTC/blob/main/ASR_modal/text_classification/dev_test/data/process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pythainlp deepcut

# %%
from pythainlp import word_tokenize
import pandas as pd


# Pytorch
from torchtext import data

# %%
df = pd.read_csv("clean_text.csv", encoding="utf-8")

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#                                           tweet_text  is_toxic
# 0  วันๆ นี่คุยกะหมา แมว หมู ไก่ ม้า ควาย มากกว่าค...         0
# 1        หล่อมากกก หล่อวัวตายควายล้มกันเลยทีเดียวววว         0
# 2  สิวเหี้ยไรขึ้นหลังหู เสียชาติเกิดมั้ย เกิดมามั...         0
# 3  อ่ะ ป่วยก็ป่วย งานจ้างก็ต้องทำ งานเรียนก็ต้องท...         0
# 4  นี่ก็เพิ่งรู้ว่า เกิดชาตินี้ชาติเดียว เป็นทั้ง...         1

# %%
from sklearn.model_selection import train_test_split
train_df,valid_df = train_test_split(df, test_size=0.2, random_state=42)
train_df = train_df.reset_index(drop=True)
valid_df = valid_df.reset_index(drop=True)

# %% [markdown]
# ### Preprocess

# %%
import re
def process_text(text):
    #tokenize
    res = [word for word in word_tokenize(res) if word and not re.search(pattern=r"\s+", string=word)]
    return  ' '.join(res)
